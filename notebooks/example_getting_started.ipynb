# %% [markdown]
# # Example Notebook: Getting Started with Python
#
# This is an example notebook to demonstrate the structure of course materials.
#
# ## Introduction
#
# Welcome to the first example notebook! This notebook demonstrates:
# - How to write markdown cells
# - How to include code examples
# - How to structure a lesson
#
# ## Basic Python Examples

# %%
# This is a simple Python example
print("Hello, Earth Sciences!")

# Basic arithmetic
x = 10
y = 5
print(f"The sum of {x} and {y} is {x + y}")

# %% [markdown]
# ## Working with Lists
#
# Let's create a simple list of temperature measurements:

# %%
# Temperature data (in Celsius)
temperatures = [15.2, 16.8, 14.5, 17.3, 18.1]

# Calculate average temperature
avg_temp = sum(temperatures) / len(temperatures)
print(f"Average temperature: {avg_temp:.1f}°C")

# %% [markdown]
# ## Exercises
#
# Try these exercises on your own:
#
# 1. Create a list of precipitation values and calculate the total
# 2. Find the maximum and minimum values in a dataset
# 3. Convert temperatures from Celsius to Fahrenheit
#
# ## Summary
#
# In this notebook, we covered:
# - Basic Python syntax
# - Working with variables
# - Simple list operations
# - Basic calculations
#
# Next, we'll explore more advanced data analysis techniques using NumPy and Pandas.
